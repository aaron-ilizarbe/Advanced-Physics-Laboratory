# %%
from pylab import*
from numpy import*

# %%
def seno1(x):
    return (10e4)*sin(10*pi*x)
x1 = linspace(0, 100, 10000)

plot(x1, seno1(x1))
xlim(6,8)
title("Vibración de la barra de acero")
xlabel("Tiempo (s)")
ylabel("Tren de onda")
show()
